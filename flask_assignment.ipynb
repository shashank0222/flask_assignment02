# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a light-weight backend framework which easy to learn and use.
#
# Some of the advantages of Flask Framework include:
#
# Lightweight backend framework with minimal dependencies.
#
# Easy to learn because of its simple and intuitive API.
#
# Flexible Framework because it allows you to customize and extend the
# framework to suit your needs easily.
#
# Highly scalable for simple applications.
#
# Easy to build a quick prototype.
#
# Routing URL is easy.
#
# Easy to develop and maintain applications.
#
# Higher compatibility with latest technologies.
#
# Codebase size is relatively smaller.
#
# Lightweight.
#
# Good documentation

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return "Hello, World!"
#
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
#
#
# OUTPUT:
#
# ![image.png](attachment:40a4fe0c-6808-4710-b21f-a05e9bab6887.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing means mapping the URLs to a specific function that will handle the logic for that URL
#
# We use app routes in Flask to map the specific URL with the associated function that is intended to perform some task. The routing technique helps a user remember application URLs and is useful to access the desired page directly without having to navigate from the home page. The route() decorator in Flask is used to bind URL to a function

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
#
# Company Name: ABC Corporation
#
# Location: India
#
# Contact Detail: 999-999-9999
#
# Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# from flask import Flask
#
# main = Flask(__name__)
#
# @main.route("/welcome")
# def welcome():
#     return  "Welcome to ABC Corporation"
#
# @main.route("/")
# def company_details():
#     return '''Company Name: ABC Corporation
#
#     Location: India
#
#     Contact Detail: 999-999-9999'''
#
# if __name__ == "__main__":
#     main.run(host = "0.0.0.0")
#
# output:
#
# ![image.png](attachment:b197171e-16f6-46ee-bc47-fd5f8e80b6e7.png)
#
# ![image.png](attachment:cf819e2e-229b-4528-ae4a-c3e1c9bb8234.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# The function used in Flask for URL Building is url_for(). It is used to build a URL to the specific function dynamically. The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL. This function is useful in the sense that we can avoid hard-coding the URLs into the templates by dynamically building them using this function.
#
# from flask import Flask , render_template , redirect , url_for
#
# app = Flask(__name__)
#
# @app.route("/")
# def welcome():
#
#     return render_template("sportsmain.html")
#
# @app.route("/cricket/<favteam>")
# def cricket(favteam):
#
#     return render_template("cricket.html" , fav = favteam)
#
# @app.route("/carrom/<favteam>")
# def carrom(favteam):
#
#     return render_template("carrom.html" , fav = favteam)
#
#
#
# @app.route("/sport/<name>/<team>")
# def game(name,team):
#
#     if name == "cricket":
#
#         return redirect(url_for("cricket" , favteam = team))
#
#
#     elif name == "carrom":
#
#         return redirect(url_for("carrom" , favteam = team))
#
#
#     else:
#
#         return render_template("sportsmain.html")
#
#
# if __name__ == "__main__":
#
#     app.run(host = "0.0.0.0")
